# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\22th'

# %%
from PIL import Image

# %%
i=Image.open('dora.jpeg')

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=219x230>

# %%
i.show()

# %%
i.save('a1.png')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'a1.png', 'dora.jpeg', 'Untitled.ipynb']

# %%
for f in os.listdir("."):
    if f.endswith(".jpeg"):
        print(f)
# Out:
# dora.jpeg

# %%
for f in os.listdir("."):
    if f.endswith(".png"):
        print(f)
# Out:
# a1.png

# %%
i=i.convert(mode='L').save('bw.jpg')
i2=Image.open('bw.jpg')
i2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 i=i.convert(mode='L').save('bw.jpg')
#       2 i2=Image.open('bw.jpg')
#       3 i2
#
# AttributeError: 'str' object has no attribute 'convert'

# %%
i = Image.open('dora.jpeg')
i= i.convert("L")

# %%
i
# Out:
# <PIL.Image.Image image mode=L size=219x230>

# %%
i=Image.open('dora.jpeg')
i=i.rotate(55)

# %%
i
# Out:
# <PIL.Image.Image image mode=RGB size=219x230>

# %%
i.show()
